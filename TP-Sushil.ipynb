# %% [markdown]
# # Text Processing Sushil

# %% [markdown]
# ## Import & Setup

# %%
# Text processing & utilities
import pandas as pd
import re
import emoji
import time
from collections import Counter

# Visualization
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# NLP: Translate, Stem, Stopword
from deep_translator import GoogleTranslator
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# Visualization setting
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Define Utility Functions

# %% [markdown]
# ### Emoji Cleaning

# %%
def remove_emoji(text):
    return emoji.replace_emoji(text, replace="") if isinstance(text, str) else text

# %%
def extract_emoji_description(text):
    return emoji.demojize(text) if isinstance(text, str) else text

# %%
def clean_emoji_desc(text):
    if isinstance(text, str):
        return text.replace("::", " ").replace(":", "").replace("-", " ").replace("_", " ")
    return text

# %% [markdown]
# ### Text Cleaning

# %%
def clean_text(text):
    if not isinstance(text, str):
        return ""
    text = text.lower()
    text = re.sub(r"http\S+|www\S+", "", text)
    text = re.sub(r"@\w+", "", text)
    text = re.sub(r"\d+", "", text)
    text = re.sub(r"[^\w\s-]", "", text).replace("-", " ")
    text = re.sub(r"\b(rt|user|hashtag|shashtag|ufc|co|uk)\b|<user>|<hashtag>", "", text)
    text = emoji.replace_emoji(text, replace="")
    text = re.sub(r"\n", " ", text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %% [markdown]
# ### Translate

# %%
def translate_text(text, source='en', target='id', retries=3):
    for attempt in range(retries):
        try:
            return GoogleTranslator(source=source, target=target).translate(text)
        except Exception as e:
            print(f"Translation error: {e}, retry {attempt+1}")
            time.sleep(5)
    return ""

# %%
def translate_column(df, col, new_col):
    df[new_col] = df[col].apply(lambda x: translate_text(x))
    return df

# %% [markdown]
# ### Slang replace

# %%
def replace_slang_words(text, slang_map):
    return " ".join([slang_map.get(word, word) for word in text.split()])

# %% [markdown]
# ### Stemming & Stopword Removal

# %%
stemmer = StemmerFactory().create_stemmer()
stopword = StopWordRemoverFactory().create_stop_word_remover()

# %%
def preprocess_indonesian(text):
    return stopword.remove(stemmer.stem(text))

# %% [markdown]
# ## Load Dataset & Emoji Preprocessing

# %%
df = pd.read_csv('dataset/Sushil/train_emoji.csv')
df["tweet without emoji"] = df["tweets"].apply(remove_emoji)
df["emoji description"] = df["emoji"].apply(extract_emoji_description).apply(clean_emoji_desc)
df["cleaned tweet"] = df["tweet without emoji"].apply(clean_text)

# %%
df_slang = pd.read_csv('dataset/OLID/slang-olid.csv')
slang_map = dict(zip(df_slang["slang word"], df_slang["formal word"]))
df["cleaned tweet"] = df["cleaned tweet"].apply(lambda x: replace_slang_words(x, slang_map))

# %% [markdown]
# ## Translate Cleaned Tweet and Emoji

# %%
df = translate_column(df, "cleaned tweet", "translated tweet")
df = translate_column(df, "emoji description", "translated emoji")
df.to_csv("dataset/Sushil/translated.csv", index=False)

# %% [markdown]
# ## Merged Validated Translation & Slang Indonesia

# %%
df_ori = pd.read_csv("dataset/Sushil/translated.csv")
df_tweet = pd.read_csv("dataset/Sushil/validated tweet.csv", 
                       quotechar='"',
                       skipinitialspace=True,
                       encoding='utf-8',
                       on_bad_lines='warn',
                       delimiter=',')
df_emoji = pd.read_csv("dataset/Sushil/validated emoji.csv")

df_ori = df_ori.dropna(subset=['cleaned tweet']).drop_duplicates(subset=['cleaned tweet'])
df_tweet = df_tweet.dropna(subset=['cleaned tweet']).drop_duplicates(subset=['cleaned tweet'])

merged = df_ori.merge(df_tweet, on="cleaned tweet", how="inner")
emoji_dict = dict(zip(df_emoji["emoji"], df_emoji["translated emoji"]))
merged["translated emoji"] = merged["emoji"].map(emoji_dict)

# %%
df_slang_indo = pd.read_csv('dataset/Sushil/slang-Sushil-indo.csv')
slang_map_indo = dict(zip(df_slang_indo["slang word"], df_slang_indo["formal word"]))
merged["validated tweet"] = merged["validated tweet"].astype(str).apply(lambda x: replace_slang_words(x.lower(), slang_map_indo))

merged["validated tweet"] = merged["validated tweet"].apply(clean_text)
merged["translated emoji"] = merged["translated emoji"].fillna("").str.lower()
merged["tweet indo with emoji desc"] = merged["validated tweet"] + " " + merged["translated emoji"]

# %% [markdown]
# ## Stemming and Stopword

# %%
merged["Text Stemmed"] = merged["validated tweet"].apply(stemmer.stem)
merged["Text with Emoji Stemmed"] = merged["tweet indo with emoji desc"].apply(stemmer.stem)

merged["No Stopword Text"] = merged["Text Stemmed"].apply(stopword.remove)
merged["Text with Emoji no Stopword"] = merged["Text with Emoji Stemmed"].apply(stopword.remove)

# %% [markdown]
# ## Save Final Dataset

# %%
merged.to_csv("dataset/Sushil/final.csv", index=False)

df_final = merged[["No Stopword Text", "Text with Emoji no Stopword", "labels"]].dropna().drop_duplicates()
df_final.to_csv("dataset/Sushil/clean.csv", index=False)

# %% [markdown]
# ## WordCloud & Frequency

# %%
hs_text = ' '.join(df_final[df_final["labels"] == 1]["No Stopword Text"])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(hs_text)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

Counter(hs_text.split()).most_common(10)
# Out:
# [('kamu', 1129),
#  ('banget', 761),
#  ('gak', 682),
#  ('cewek', 662),
#  ('sial', 595),
#  ('orang', 522),
#  ('sama', 478),
#  ('saya', 384),
#  ('benci', 362),
#  ('jadi', 298)]
